# %% [markdown]
# Comprehension in python
#
# it is an effective way to create collection such as list , dict , and sets in python
#
# they are allow you to generate , transform , and filter data using single line of code
#
# 1 List
#
# 2 Dict
#
# 3 Set

# %% [markdown]
# LIST COMPREHENSION
#
# it is used to create new list from existing iterable
#
# in this one insted of using for loop and append() methods we can create list directly
#
# syntax
#
# [new_item for item  in iterable if condition]
#
# sytanx if else
#
# [true_value if condition else false_value for item in iterables]

# %%
list = []
for i in range(1,6):
    list.append(i**2)
print(list)
list = [x**2 for x in range(1,6)]
print(list)
# Out:
# [1, 4, 9, 16, 25]
# [1, 4, 9, 16, 25]

# %%
even = [x for x in range(1,11) if x%2==0 ]
print(even)
# Out:
# [2, 4, 6, 8, 10]

# %%
{key : value for item in iterable if condition}

# %%
mydict= {n : n**3 for n in range(5) if n%2==0}
print(mydict)
# Out:
# {0: 0, 2: 8, 4: 64}

# %%
arr = [10,20,30,40,50]
t = 30
found = False

l = [x if x == t else "non" for x in arr]
print(l)
# Out:
# ['non', 'non', 30, 'non', 'non']

# %%
def binary_search(arr, target):
    """
    Performs an iterative binary search on a sorted list.
    Returns the index of the target if found, otherwise returns -1.
    """
    low = 0
    high = len(arr) - 1

    while low <= high:
        # Calculate the middle index
        mid = (low + high) // 2
        
        # Check if the target is present at the mid position
        if arr[mid] == target:
            return mid
        
        # If target is greater, ignore the left half
        elif arr[mid] < target:
            low = mid + 1
            
        # If target is smaller, ignore the right half
        else:
            high = mid - 1

    # Element was not present in the list
    return -1

# --- Example Usage ---
if __name__ == "__main__":
    # The input list MUST be sorted
    numbers = [2, 5, 8, 12, 16, 23, 38, 56, 72, 91]
    target_value = 23

    result = binary_search(numbers, target_value)

    if result != -1:
        print(f"Element found at index: {result}")
    else:
        print("Element not found in the list.")
# Out:
# Element found at index: 5
